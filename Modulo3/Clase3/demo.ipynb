# %% [markdown]
# <h2 style="color:#1f77b4;">Lección 3: Obtención de datos desde archivos</h2>

# %% [markdown]
# <h3>Parte 1</h3>

# %% [markdown]
# <h4>Leyendo un archivo CSV</h4>

# %%
import pandas as pd

# Leer un archivo CSV básico
df = pd.read_csv('Titanic-Dataset.csv')

# Mostrar las primeras filas
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <h5>Opciones para leer archivos CSV</h5>

# %% [markdown]
# <p>1. Leer un archivo CSV con punto y coma como delimitador</p>

# %%
df = pd.read_csv("datos_punto_y_coma.csv", sep=";")
print(df.head())
# Out:
#    id nombre  edad  ventas
# 0   1    Ana    25    1200
# 1   2   Juan    30    1500
# 2   3  María    28    1100
# 3   4  Pedro    35    1800

# %% [markdown]
# <p>2. Leer un archivo CSV con tabulación como delimitador</p>

# %%
df = pd.read_csv("datos_tab.csv", sep="\t")
print(df.head())
# Out:
#    id nombre  edad  ventas
# 0   1    Ana    25    1200
# 1   2   Juan    30    1500
# 2   3  María    28    1100
# 3   4  Pedro    35    1800

# %% [markdown]
# <h4>Escribiendo un archivo CSV</h4>
# Para guardar un DataFrame en un archivo CSV, se utiliza el método to_csv().

# %%
df = pd.DataFrame({
    "id": [1, 2, 3, 4],
    "nombre": ["Ana", "Juan", "María", "Pedro"],
    "edad": [25, 30, 28, 35],
    "ventas": [1200, 1500, 1100, 1800]
})

print("DataFrame original:")
print(df)

# 2) Guardar un DataFrame en un archivo CSV (incluye el índice por defecto)
df.to_csv("nuevo_datos.csv")
print("\nSe creó: nuevo_datos.csv (con índice)")

# 3) Guardar sin incluir el índice
df.to_csv("nuevo_datos_sin_indice.csv", index=False)
print("Se creó: nuevo_datos_sin_indice.csv (sin índice)")
# Out:
# DataFrame original:
#    id nombre  edad  ventas
# 0   1    Ana    25    1200
# 1   2   Juan    30    1500
# 2   3  María    28    1100
# 3   4  Pedro    35    1800
#
# Se creó: nuevo_datos.csv (con índice)
# Se creó: nuevo_datos_sin_indice.csv (sin índice)

# %% [markdown]
# <h3>Archivos Excel</h3>

# %%
import pandas as pd

excel_path="Valor del Dolar.xlsx"

# Leer un archivo Excel
df = pd.read_excel(excel_path)

# Mostrar las primeras filas
print(df.head())
# Out:
#        Fecha  Día Atributo    Valor
# 0 2025-01-02    2      Ene   996.46
# 1 2025-01-03    3      Ene   999.84
# 2 2025-01-06    6      Ene  1011.82
# 3 2025-01-07    7      Ene  1010.98
# 4 2025-01-08    8      Ene  1005.85

# %%
# si da error Instalar -> pip install openpyxl

# %%
# 1) Ver hojas disponibles
xls = pd.ExcelFile(excel_path)
print("Hojas disponibles:", xls.sheet_names)
# Out:
# Hojas disponibles: ['Tabla 11', 'Hoja1']

# %%
# 2) Leer una hoja por nombre (ajusta el nombre real)
df = pd.read_excel(excel_path, sheet_name=xls.sheet_names[0])
display(df.head())
# Out:
#        Fecha  Día Atributo    Valor
# 0 2025-01-02    2      Ene   996.46
# 1 2025-01-03    3      Ene   999.84
# 2 2025-01-06    6      Ene  1011.82
# 3 2025-01-07    7      Ene  1010.98
# 4 2025-01-08    8      Ene  1005.85

# %%
# 3) Leer una hoja por índice
df0 = pd.read_excel(excel_path, sheet_name=0)
df0
# Out:
#          Fecha  Día Atributo    Valor
# 0   2025-01-02    2      Ene   996.46
# 1   2025-01-03    3      Ene   999.84
# 2   2025-01-06    6      Ene  1011.82
# 3   2025-01-07    7      Ene  1010.98
# 4   2025-01-08    8      Ene  1005.85
# ..         ...  ...      ...      ...
# 246 2025-12-27   27      Dic      NaN
# 247 2025-12-28   28      Dic      NaN
# 248 2025-12-29   29      Dic      NaN
# 249 2025-12-30   30      Dic      NaN
# 250 2025-12-31   31      Dic      NaN
#
# [251 rows x 4 columns]

# %%
# 4) Leer múltiples hojas (diccionario de DataFrames)
dfs = pd.read_excel(excel_path, sheet_name=xls.sheet_names[:2])
print("Hojas cargadas:", list(dfs.keys()))
# Out:
# Hojas cargadas: ['Tabla 11', 'Hoja1']

# %%
dfs
# Out:
# {'Tabla 11':          Fecha  Día Atributo    Valor
#  0   2025-01-02    2      Ene   996.46
#  1   2025-01-03    3      Ene   999.84
#  2   2025-01-06    6      Ene  1011.82
#  3   2025-01-07    7      Ene  1010.98
#  4   2025-01-08    8      Ene  1005.85
#  ..         ...  ...      ...      ...
#  246 2025-12-27   27      Dic      NaN
#  247 2025-12-28   28      Dic      NaN
#  248 2025-12-29   29      Dic      NaN
#  249 2025-12-30   30      Dic      NaN
#  250 2025-12-31   31      Dic      NaN
#
#  [251 rows x 4 columns],
#  'Hoja1': Empty DataFrame
#  Columns: []
#  Index: []}

# %% [markdown]
# <h2>Leer tablas web con pandas</h2>

# %%
#%pip install requests

# %%
#%pip install lxml

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_por_PIB_(PPA)_per_c%C3%A1pita"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0 Safari/537.36",
    "Accept-Language": "es-ES,es;q=0.9"
}

html = requests.get(url, headers=headers, timeout=30).text
df_list = pd.read_html(StringIO(html))

# Ver cuántas tablas y una “vista rápida” de cada una
print("Cantidad de tablas:", len(df_list))
for i, t in enumerate(df_list):
    print(i, t.shape, "->", list(t.columns)[:6])
# Out:
# Cantidad de tablas: 204
# 0 (1, 3) -> [0, 1, 2]
# 1 (596, 4) -> [0, 1, 2, 3]
# 2 (398, 4) -> ['Pos.', 'País', 'PIB per cápita (PPA) Dólares internacionales', 'Δ']
# 3 (1, 2) -> [0, 1]
# 4 (1, 2) -> [0, 1]
# 5 (1, 2) -> [0, 1]
# 6 (1, 2) -> [0, 1]
# 7 (1, 2) -> [0, 1]
# 8 (1, 2) -> [0, 1]
# 9 (1, 2) -> [0, 1]
# 10 (1, 2) -> [0, 1]
# 11 (1, 2) -> [0, 1]
# 12 (1, 2) -> [0, 1]
# 13 (1, 2) -> [0, 1]
# 14 (1, 2) -> [0, 1]
# 15 (1, 2) -> [0, 1]
# 16 (1, 2) -> [0, 1]
# 17 (1, 2) -> [0, 1]
# 18 (1, 2) -> [0, 1]
# 19 (1, 2) -> [0, 1]
# 20 (1, 2) -> [0, 1]
# 21 (1, 2) -> [0, 1]
# 22 (1, 2) -> [0, 1]
# 23 (1, 2) -> [0, 1]
# 24 (1, 2) -> [0, 1]
# 25 (1, 2) -> [0, 1]
# 26 (1, 2) -> [0, 1]
# 27 (1, 2) -> [0, 1]
# 28 (1, 2) -> [0, 1]
# 29 (1, 2) -> [0, 1]
# 30 (1, 2) -> [0, 1]
# 31 (1, 2) -> [0, 1]
# 32 (1, 2) -> [0, 1]
# 33 (1, 2) -> [0, 1]
# 34 (1, 2) -> [0, 1]
# 35 (1, 2) -> [0, 1]
# 36 (1, 2) -> [0, 1]
# 37 (1, 2) -> [0, 1]
# 38 (1, 2) -> [0, 1]
# 39 (1, 2) -> [0, 1]
# 40 (1, 2) -> [0, 1]
# 41 (1, 2) -> [0, 1]
# 42 (1, 2) -> [0, 1]
# 43 (1, 2) -> [0, 1]
# 44 (1, 2) -> [0, 1]
# 45 (1, 2) -> [0, 1]
# 46 (1, 2) -> [0, 1]
# 47 (1, 2) -> [0, 1]
# 48 (1, 2) -> [0, 1]
# 49 (1, 2) -> [0, 1]
# 50 (1, 2) -> [0, 1]
# 51 (1, 2) -> [0, 1]
# 52 (1, 2) -> [0, 1]
# 53 (1, 2) -> [0, 1]
# 54 (1, 2) -> [0, 1]
# 55 (1, 2) -> [0, 1]
# 56 (1, 2) -> [0, 1]
# 57 (1, 2) -> [0, 1]
# 58 (1, 2) -> [0, 1]
# 59 (1, 2) -> [0, 1]
# 60 (1, 2) -> [0, 1]
# 61 (1, 2) -> [0, 1]
# 62 (1, 2) -> [0, 1]
# 63 (1, 2) -> [0, 1]
# 64 (1, 2) -> [0, 1]
# 65 (1, 2) -> [0, 1]
# 66 (1, 2) -> [0, 1]
# 67 (1, 2) -> [0, 1]
# 68 (1, 2) -> [0, 1]
# 69 (1, 2) -> [0, 1]
# 70 (1, 2) -> [0, 1]
# 71 (1, 2) -> [0, 1]
# 72 (1, 2) -> [0, 1]
# 73 (1, 2) -> [0, 1]
# 74 (1, 2) -> [0, 1]
# 75 (1, 2) -> [0, 1]
# 76 (1, 2) -> [0, 1]
# 77 (1, 2) -> [0, 1]
# 78 (1, 2) -> [0, 1]
# 79 (1, 2) -> [0, 1]
# 80 (1, 2) -> [0, 1]
# 81 (1, 2) -> [0, 1]
# 82 (1, 2) -> [0, 1]
# 83 (1, 2) -> [0, 1]
# 84 (1, 2) -> [0, 1]
# 85 (1, 2) -> [0, 1]
# 86 (1, 2) -> [0, 1]
# 87 (1, 2) -> [0, 1]
# 88 (1, 2) -> [0, 1]
# 89 (1, 2) -> [0, 1]
# 90 (1, 2) -> [0, 1]
# 91 (1, 2) -> [0, 1]
# 92 (1, 2) -> [0, 1]
# 93 (1, 2) -> [0, 1]
# 94 (1, 2) -> [0, 1]
# 95 (1, 2) -> [0, 1]
# 96 (1, 2) -> [0, 1]
# 97 (1, 2) -> [0, 1]
# 98 (1, 2) -> [0, 1]
# 99 (1, 2) -> [0, 1]
# 100 (1, 2) -> [0, 1]
# 101 (1, 2) -> [0, 1]
# 102 (1, 2) -> [0, 1]
# 103 (1, 2) -> [0, 1]
# 104 (1, 2) -> [0, 1]
# 105 (1, 2) -> [0, 1]
# 106 (1, 2) -> [0, 1]
# 107 (1, 2) -> [0, 1]
# 108 (1, 2) -> [0, 1]
# 109 (1, 2) -> [0, 1]
# 110 (1, 2) -> [0, 1]
# 111 (1, 2) -> [0, 1]
# 112 (1, 2) -> [0, 1]
# 113 (1, 2) -> [0, 1]
# 114 (1, 2) -> [0, 1]
# 115 (1, 2) -> [0, 1]
# 116 (1, 2) -> [0, 1]
# 117 (1, 2) -> [0, 1]
# 118 (1, 2) -> [0, 1]
# 119 (1, 2) -> [0, 1]
# 120 (1, 2) -> [0, 1]
# 121 (1, 2) -> [0, 1]
# 122 (1, 2) -> [0, 1]
# 123 (1, 2) -> [0, 1]
# 124 (1, 2) -> [0, 1]
# 125 (1, 2) -> [0, 1]
# 126 (1, 2) -> [0, 1]
# 127 (1, 2) -> [0, 1]
# 128 (1, 2) -> [0, 1]
# 129 (1, 2) -> [0, 1]
# 130 (1, 2) -> [0, 1]
# 131 (1, 2) -> [0, 1]
# 132 (1, 2) -> [0, 1]
# 133 (1, 2) -> [0, 1]
# 134 (1, 2) -> [0, 1]
# 135 (1, 2) -> [0, 1]
# 136 (1, 2) -> [0, 1]
# 137 (1, 2) -> [0, 1]
# 138 (1, 2) -> [0, 1]
# 139 (1, 2) -> [0, 1]
# 140 (1, 2) -> [0, 1]
# 141 (1, 2) -> [0, 1]
# 142 (1, 2) -> [0, 1]
# 143 (1, 2) -> [0, 1]
# 144 (1, 2) -> [0, 1]
# 145 (1, 2) -> [0, 1]
# 146 (1, 2) -> [0, 1]
# 147 (1, 2) -> [0, 1]
# 148 (1, 2) -> [0, 1]
# 149 (1, 2) -> [0, 1]
# 150 (1, 2) -> [0, 1]
# 151 (1, 2) -> [0, 1]
# 152 (1, 2) -> [0, 1]
# 153 (1, 2) -> [0, 1]
# 154 (1, 2) -> [0, 1]
# 155 (1, 2) -> [0, 1]
# 156 (1, 2) -> [0, 1]
# 157 (1, 2) -> [0, 1]
# 158 (1, 2) -> [0, 1]
# 159 (1, 2) -> [0, 1]
# 160 (1, 2) -> [0, 1]
# 161 (1, 2) -> [0, 1]
# 162 (1, 2) -> [0, 1]
# 163 (1, 2) -> [0, 1]
# 164 (1, 2) -> [0, 1]
# 165 (1, 2) -> [0, 1]
# 166 (1, 2) -> [0, 1]
# 167 (1, 2) -> [0, 1]
# 168 (1, 2) -> [0, 1]
# 169 (1, 2) -> [0, 1]
# 170 (1, 2) -> [0, 1]
# 171 (1, 2) -> [0, 1]
# 172 (1, 2) -> [0, 1]
# 173 (1, 2) -> [0, 1]
# 174 (1, 2) -> [0, 1]
# 175 (1, 2) -> [0, 1]
# 176 (1, 2) -> [0, 1]
# 177 (1, 2) -> [0, 1]
# 178 (1, 2) -> [0, 1]
# 179 (1, 2) -> [0, 1]
# 180 (1, 2) -> [0, 1]
# 181 (1, 2) -> [0, 1]
# 182 (1, 2) -> [0, 1]
# 183 (1, 2) -> [0, 1]
# 184 (1, 2) -> [0, 1]
# 185 (1, 2) -> [0, 1]
# 186 (1, 2) -> [0, 1]
# 187 (1, 2) -> [0, 1]
# 188 (1, 2) -> [0, 1]
# 189 (1, 2) -> [0, 1]
# 190 (1, 2) -> [0, 1]
# 191 (1, 2) -> [0, 1]
# 192 (1, 2) -> [0, 1]
# 193 (1, 2) -> [0, 1]
# 194 (1, 2) -> [0, 1]
# 195 (1, 2) -> [0, 1]
# 196 (1, 2) -> [0, 1]
# 197 (1, 2) -> [0, 1]
# 198 (1, 2) -> [0, 1]
# 199 (1, 2) -> [0, 1]
# 200 (1, 2) -> [0, 1]
# 201 (1, 2) -> [0, 1]
# 202 (194, 3) -> ['Pos.', 'País', 'Dólares inter- nacionales']
# 203 (1, 2) -> [0, 1]

# %%
df = df_list[2].copy()
df.head()
# Out:
#   Pos.        País PIB per cápita (PPA) Dólares internacionales       Δ
# 0    1  Luxemburgo                                      143 314  ▼ 3,4%
# 1  NaN     143 314                                          NaN     NaN
# 2    2    Singapur                                      141 500  ▼ 3,7%
# 3  NaN     141 500                                          NaN     NaN
# 4    3     Irlanda                                      127 623  ▼ 5,7%

# %%
# 5) Renombrar columnas (explícito)
df = df.rename(columns={
    "Pos.": "posicion",
    "País": "pais",
    "PIB per cápita (PPA) Dólares internacionales": "pib_ppa_per_capita",
    "Δ": "delta"
})
df.head()
# Out:
#   posicion        pais pib_ppa_per_capita   delta
# 0        1  Luxemburgo            143 314  ▼ 3,4%
# 1      NaN     143 314                NaN     NaN
# 2        2    Singapur            141 500  ▼ 3,7%
# 3      NaN     141 500                NaN     NaN
# 4        3     Irlanda            127 623  ▼ 5,7%

# %%
# Limpieza
# - quitar referencias tipo [1], [nota 2], etc.
df = df.replace(r"\[.*?\]", "", regex=True)
df.head()
# Out:
#   posicion        pais pib_ppa_per_capita   delta
# 0        1  Luxemburgo            143 314  ▼ 3,4%
# 1      NaN     143 314                NaN     NaN
# 2        2    Singapur            141 500  ▼ 3,7%
# 3      NaN     141 500                NaN     NaN
# 4        3     Irlanda            127 623  ▼ 5,7%

# %%
# - limpiar espacios raros
df["pais"] = df["pais"].astype(str).str.strip()
df.head(100)
# Out:
#    posicion                                  pais pib_ppa_per_capita   delta
# 0         1                            Luxemburgo            143 314  ▼ 3,4%
# 1       NaN                               143 314                NaN     NaN
# 2         2                              Singapur            141 500  ▼ 3,7%
# 3       NaN                               141 500                NaN     NaN
# 4         3                               Irlanda            127 623  ▼ 5,7%
# ..      ...                                   ...                ...     ...
# 95      NaN                                47 903                NaN     NaN
# 96        —                           Puerto Rico             47 699       —
# 97      NaN                                47 699                NaN     NaN
# 98        —  Islas Vírgenes de los Estados Unidos             46 238       —
# 99      NaN                                46 238                NaN     NaN
#
# [100 rows x 4 columns]

# %%
# Convertir pib a número (quita separadores y cosas no numéricas)
df["pib_ppa_per_capita"] = (
    df["pib_ppa_per_capita"]
    .astype(str)                                # fuerza a que todos los valores de la columna pais sean texto
    .str.replace(r"[^\d,.\-]", "", regex=True)  # deja solo dígitos y signos
    .str.replace(".", "", regex=False)          # por si viene con separador de miles "."
    .str.replace(",", "", regex=False)          # por si viene con separador de miles ","
)
df.head(100)
# Out:
#    posicion                                  pais pib_ppa_per_capita   delta
# 0         1                            Luxemburgo             143314  ▼ 3,4%
# 1       NaN                               143 314                        NaN
# 2         2                              Singapur             141500  ▼ 3,7%
# 3       NaN                               141 500                        NaN
# 4         3                               Irlanda             127623  ▼ 5,7%
# ..      ...                                   ...                ...     ...
# 95      NaN                                47 903                        NaN
# 96        —                           Puerto Rico              47699       —
# 97      NaN                                47 699                        NaN
# 98        —  Islas Vírgenes de los Estados Unidos              46238       —
# 99      NaN                                46 238                        NaN
#
# [100 rows x 4 columns]

# %%
# Convertir pib a número 
df["pib_ppa_per_capita"] = pd.to_numeric(df["pib_ppa_per_capita"], errors="coerce")
df.head(100)
# Out:
#    posicion                                  pais  pib_ppa_per_capita   delta
# 0         1                            Luxemburgo            143314.0  ▼ 3,4%
# 1       NaN                               143 314                 NaN     NaN
# 2         2                              Singapur            141500.0  ▼ 3,7%
# 3       NaN                               141 500                 NaN     NaN
# 4         3                               Irlanda            127623.0  ▼ 5,7%
# ..      ...                                   ...                 ...     ...
# 95      NaN                                47 903                 NaN     NaN
# 96        —                           Puerto Rico             47699.0       —
# 97      NaN                                47 699                 NaN     NaN
# 98        —  Islas Vírgenes de los Estados Unidos             46238.0       —
# 99      NaN                                46 238                 NaN     NaN
#
# [100 rows x 4 columns]

# %%
# - convertir posición a número
df["posicion"] = pd.to_numeric(df["posicion"], errors="coerce")
df.head(100)
# Out:
#     posicion                                  pais  pib_ppa_per_capita   delta
# 0        1.0                            Luxemburgo            143314.0  ▼ 3,4%
# 1        NaN                               143 314                 NaN     NaN
# 2        2.0                              Singapur            141500.0  ▼ 3,7%
# 3        NaN                               141 500                 NaN     NaN
# 4        3.0                               Irlanda            127623.0  ▼ 5,7%
# ..       ...                                   ...                 ...     ...
# 95       NaN                                47 903                 NaN     NaN
# 96       NaN                           Puerto Rico             47699.0       —
# 97       NaN                                47 699                 NaN     NaN
# 98       NaN  Islas Vírgenes de los Estados Unidos             46238.0       —
# 99       NaN                                46 238                 NaN     NaN
#
# [100 rows x 4 columns]

# %%
# - eliminar filas con faltantes relevantes
df = df.dropna(subset=["posicion", "pais", "pib_ppa_per_capita"])
df.head(100)
# Out:
#      posicion                 pais  pib_ppa_per_capita   delta
# 0         1.0           Luxemburgo            143314.0  ▼ 3,4%
# 2         2.0             Singapur            141500.0  ▼ 3,7%
# 4         3.0              Irlanda            127623.0  ▼ 5,7%
# 6         4.0         Catar (2022)            121124.0  ▲ 1,1%
# 12        5.0              Noruega            104459.0  ▼ 0,6%
# ..        ...                  ...                 ...     ...
# 214      94.0             Moldavia             17384.0  ▲ 2,9%
# 216      95.0  Turkmenistán (2019)             17100.0       —
# 218      96.0              Argelia             17027.0  ▲ 2,5%
# 220      97.0                 Perú             16717.0  ▼ 1,4%
# 222      98.0              Ecuador             15870.0  ▲ 1,3%
#
# [100 rows x 4 columns]

# %% [markdown]
# 1) sort_values("posicion"): Ordena las filas según la columna posicion.
# 2) reset_index(drop=True): reset_index() crea un índice nuevo 0,1,2,3… y drop=True significa: No guardes el índice anterior como una columna extra

# %%
# Ordenar por posición
df = df.sort_values("posicion").reset_index(drop=True)
df.head(100)
# Out:
#     posicion                 pais  pib_ppa_per_capita   delta
# 0        1.0           Luxemburgo            143314.0  ▼ 3,4%
# 1        2.0             Singapur            141500.0  ▼ 3,7%
# 2        3.0              Irlanda            127623.0  ▼ 5,7%
# 3        4.0         Catar (2022)            121124.0  ▲ 1,1%
# 4        5.0              Noruega            104459.0  ▼ 0,6%
# ..       ...                  ...                 ...     ...
# 95      94.0             Moldavia             17384.0  ▲ 2,9%
# 96      95.0  Turkmenistán (2019)             17100.0       —
# 97      96.0              Argelia             17027.0  ▲ 2,5%
# 98      97.0                 Perú             16717.0  ▼ 1,4%
# 99      98.0              Ecuador             15870.0  ▲ 1,3%
#
# [100 rows x 4 columns]

# %%
# 7) Guardar a CSV
df.to_csv("pib_ppa_per_capita.csv", index=False, encoding="utf-8")

# %% [markdown]
# <h3>Parte 2</h3>

# %% [markdown]
# Datos desde https://datosabiertos.fonasa.cl/
#
# Archivo_desde = "https://public.tableau.com/views/PropuestaTableroGRD/PropuestaTableroGRD?%3AshowVizHome=no#1"

# %% [markdown]
# <h3>Lectura por fragmentos (chunks)</h3>

# %% [markdown]
# <p>chunks es una forma de leer el archivo por partes, en vez de cargarlo completo en memoria.</p>
# <p>Pandas no te entrega un DataFrame único.
# Te entrega un iterador que va produciendo DataFrames de 1000 filas cada vez.
# </p>
#
# En la práctica significa:
# * lees 1000 filas → las procesas → sigues con las siguientes 1000
# * así puedes trabajar con archivos grandes sin “reventar” la RAM
# * y puedes ir guardando resultados a medida que avanzas

# %%
# Leer un archivo CSV en fragmentos de 1000 filas
chunks = pd.read_csv(
    "GRD_PUBLICO_2019.txt",
    sep="|",                 # ajusta si corresponde
    encoding="latin1",
    chunksize=1000,
    engine="python",         # más tolerante que el C engine
    on_bad_lines="skip"     # salta filas problemáticas
)

# %%
chunk1 = next(chunks)  # primeras 1000
chunk1.shape

# %%
chunk1.head()
# Out:
#    COD_HOSPITAL  CIP_ENCRIPTADO    SEXO FECHA_NACIMIENTO  ETNIA   PROVINCIA  \
# 0        118100         1314867   MUJER       1988-06-19  OTRO   CONCEPCION
# 1        118100         1354418   MUJER       1988-03-27  OTRO   CONCEPCION
# 2        118100          239861   MUJER       2017-06-17  OTRO   CONCEPCION
# 3        118100          330326  HOMBRE       2017-12-04  OTRO   CONCEPCION
# 4        118100         1369293   MUJER       1995-12-06  OTRO   CONCEPCION
#
#                 COMUNA NACIONALIDAD                       PREVISION  \
# 0  SAN PEDRO DE LA PAZ        CHILE  FONASA INSTITUCIONAL - (MAI) A
# 1  SAN PEDRO DE LA PAZ        CHILE  FONASA INSTITUCIONAL - (MAI) D
# 2          CONCEPCIÃN        CHILE  FONASA INSTITUCIONAL - (MAI) B
# 3          CONCEPCIÃN        CHILE  FONASA INSTITUCIONAL - (MAI) A
# 4              FLORIDA        CHILE  FONASA INSTITUCIONAL - (MAI) C
#
#   SERVICIO_SALUD  ... FECHAPROCEDIMIENTO1 FECHAINTERV1  \
# 0    CONCEPCIÃN  ...                 NaN   2019-03-02
# 1    CONCEPCIÃN  ...                 NaN          NaN
# 2    CONCEPCIÃN  ...                 NaN          NaN
# 3    CONCEPCIÃN  ...                 NaN          NaN
# 4    CONCEPCIÃN  ...                 NaN          NaN
#
#      ESPECIALIDADINTERVENCION MEDICOALTA_ENCRIPTADO USOSPABELLON  \
# 0  OBSTETRICIA Y GINECOLOGÃA                  2932          1.0
# 1                         NaN                  2932          NaN
# 2                         NaN                  2932          NaN
# 3                         NaN                  2932          NaN
# 4                         NaN                  2932          NaN
#
#   IR_29301_COD_GRD IR_29301_PESO IR_29301_SEVERIDAD IR_29301_MORTALIDAD  \
# 0           146102        0,5744                  2                   1
# 1           134161        0,2951                  1                   1
# 2            64182        0,6736                  2                   2
# 3            64172        0,5475                  2                   2
# 4           134141        0,3107                  1                   1
#
#   HOSPPROCEDENCIA
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 129 columns]

# %%
chunk2 = next(chunks)  # siguientes 1000
chunk2.shape
# Out:
# (1000, 129)

# %%
chunk1.to_csv("chunk1.csv", index=False, encoding="utf-8")

# %% [markdown]
# <h3>Selección de columnas específicas</h3>

# %%
# Leer solo las columnas necesarias
columnas = ['CIP_ENCRIPTADO','SEXO','FECHA_NACIMIENTO']
df = pd.read_csv('chunk1.csv', usecols=columnas)
df.head()
# Out:
#    CIP_ENCRIPTADO    SEXO FECHA_NACIMIENTO
# 0         1314867   MUJER       1988-06-19
# 1         1354418   MUJER       1988-03-27
# 2          239861   MUJER       2017-06-17
# 3          330326  HOMBRE       2017-12-04
# 4         1369293   MUJER       1995-12-06

# %% [markdown]
# <h3>Especificación de tipos de datos</h3>
# Definir los tipos de datos de antemano puede mejorar significativamente el rendimiento y reducir el uso de memoria:
#
# Especificar tipos de datos precisos puede reducir el uso de memoria hasta en un 50% en algunos casos

# %%
# Definir tipos de datos para cada columna
tipos = {
    'COD_HOSPITAL': 'int32',
    'CIP_ENCRIPTADO': 'int32'
}

# Leer el archivo con los tipos especificados
df = pd.read_csv('chunk1.csv', dtype=tipos, parse_dates=['FECHA_NACIMIENTO'])
df.head()
# Out:
#    COD_HOSPITAL  CIP_ENCRIPTADO    SEXO FECHA_NACIMIENTO  ETNIA   PROVINCIA  \
# 0        118100         1314867   MUJER       1988-06-19  OTRO   CONCEPCION
# 1        118100         1354418   MUJER       1988-03-27  OTRO   CONCEPCION
# 2        118100          239861   MUJER       2017-06-17  OTRO   CONCEPCION
# 3        118100          330326  HOMBRE       2017-12-04  OTRO   CONCEPCION
# 4        118100         1369293   MUJER       1995-12-06  OTRO   CONCEPCION
#
#                 COMUNA NACIONALIDAD                       PREVISION  \
# 0  SAN PEDRO DE LA PAZ        CHILE  FONASA INSTITUCIONAL - (MAI) A
# 1  SAN PEDRO DE LA PAZ        CHILE  FONASA INSTITUCIONAL - (MAI) D
# 2          CONCEPCIÃN        CHILE  FONASA INSTITUCIONAL - (MAI) B
# 3          CONCEPCIÃN        CHILE  FONASA INSTITUCIONAL - (MAI) A
# 4              FLORIDA        CHILE  FONASA INSTITUCIONAL - (MAI) C
#
#   SERVICIO_SALUD  ... FECHAPROCEDIMIENTO1 FECHAINTERV1  \
# 0    CONCEPCIÃN  ...                 NaN   2019-03-02
# 1    CONCEPCIÃN  ...                 NaN          NaN
# 2    CONCEPCIÃN  ...                 NaN          NaN
# 3    CONCEPCIÃN  ...                 NaN          NaN
# 4    CONCEPCIÃN  ...                 NaN          NaN
#
#      ESPECIALIDADINTERVENCION MEDICOALTA_ENCRIPTADO USOSPABELLON  \
# 0  OBSTETRICIA Y GINECOLOGÃA                  2932          1.0
# 1                         NaN                  2932          NaN
# 2                         NaN                  2932          NaN
# 3                         NaN                  2932          NaN
# 4                         NaN                  2932          NaN
#
#   IR_29301_COD_GRD IR_29301_PESO IR_29301_SEVERIDAD IR_29301_MORTALIDAD  \
# 0           146102        0,5744                  2                   1
# 1           134161        0,2951                  1                   1
# 2            64182        0,6736                  2                   2
# 3            64172        0,5475                  2                   2
# 4           134141        0,3107                  1                   1
#
#   HOSPPROCEDENCIA
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 129 columns]

# %% [markdown]
# <h3>Filtrado durante la lectura</h3>
# Es posible aplicar filtros durante la lectura para cargar solo las filas que cumplen ciertas condiciones:

# %%
# Leer solo las filas que cumplen la condición
df = pd.read_csv('chunk1.csv', 
                chunksize=1000, 
                iterator=True)
df_filtrado = pd.concat([chunk[chunk['SEXO'] == "MUJER"] for chunk in df])

# %%
df_filtrado.shape
# Out:
# (618, 129)

# %%
df_filtrado["SEXO"].unique()
# Out:
# array(['MUJER'], dtype=object)

# %% [markdown]
# <h3>Ejemplo de integración completa</h3>

# %%
import pandas as pd

data = [
    {"Gasto": 120.5, "Frecuencia": 2, "Categoría": "Básico"},
    {"Gasto": 85.0, "Frecuencia": 1, "Categoría": "Básico"},
    {"Gasto": 300.0, "Frecuencia": 4, "Categoría": "Premium"},
    {"Gasto": 450.75, "Frecuencia": 6, "Categoría": "Premium"},
    {"Gasto": 210.2, "Frecuencia": 3, "Categoría": "Estándar"},
    {"Gasto": 190.0, "Frecuencia": 3, "Categoría": "Estándar"},
    {"Gasto": 560.0, "Frecuencia": 7, "Categoría": "Premium"},
    {"Gasto": 95.5, "Frecuencia": 2, "Categoría": "Básico"},
    {"Gasto": None, "Frecuencia": 5, "Categoría": "Estándar"},
    {"Gasto": 180.0, "Frecuencia": None, "Categoría": "Básico"},
    {"Gasto": 275.0, "Frecuencia": 4, "Categoría": "Estándar"},
    {"Gasto": 620.3, "Frecuencia": 8, "Categoría": "Premium"},
]

pd.DataFrame(data).to_csv("clientes.csv", index=False, encoding="utf-8")

# %%
#%pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from seaborn) (2.4.0)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
#%pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from scikit-learn) (2.4.0)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.0-cp311-cp311-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp311-cp311-macosx_10_9_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 3.3 MB/s  0:00:02m0:00:0100:01m
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.0-cp311-cp311-macosx_14_0_x86_64.whl (22.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.5/22.5 MB 5.6 MB/s  0:00:03m0:00:0100:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.0 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# 1. Obtener datos
df = pd.read_csv('clientes.csv')

# 2. Procesar datos
df = df.dropna()
df['Gasto'] = df['Gasto'].astype(float)
df['Frecuencia'] = df['Frecuencia'].astype(int)

# 3. Análisis exploratorio
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Gasto', y='Frecuencia', hue='Categoría')
plt.title('Relación entre Gasto y Frecuencia por Categoría')
plt.savefig('analisis_exploratorio.png')

# 4. Aplicar modelo
X = df[['Gasto', 'Frecuencia']]
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(X)

# 5. Guardar resultados
df.to_excel('clientes_segmentados.xlsx', index=False)

# %% [markdown]
# <h3>Manejo de datos faltantes</h3>

# %%
df = pd.read_csv('clientes.csv')
df
# Out:
#      Gasto  Frecuencia Categoría
# 0   120.50         2.0    Básico
# 1    85.00         1.0    Básico
# 2   300.00         4.0   Premium
# 3   450.75         6.0   Premium
# 4   210.20         3.0  Estándar
# 5   190.00         3.0  Estándar
# 6   560.00         7.0   Premium
# 7    95.50         2.0    Básico
# 8      NaN         5.0  Estándar
# 9   180.00         NaN    Básico
# 10  275.00         4.0  Estándar
# 11  620.30         8.0   Premium

# %%
# Detectar valores faltantes
df.isnull().sum()
# Out:
# Gasto         1
# Frecuencia    1
# Categoría     0
# dtype: int64

# %%
# Eliminar filas con valores faltantes
df_limpio = df.dropna()
df_limpio.isnull().sum()
# Out:
# Gasto         0
# Frecuencia    0
# Categoría     0
# dtype: int64

# %%
df_limpio
# Out:
#      Gasto  Frecuencia Categoría
# 0   120.50         2.0    Básico
# 1    85.00         1.0    Básico
# 2   300.00         4.0   Premium
# 3   450.75         6.0   Premium
# 4   210.20         3.0  Estándar
# 5   190.00         3.0  Estándar
# 6   560.00         7.0   Premium
# 7    95.50         2.0    Básico
# 10  275.00         4.0  Estándar
# 11  620.30         8.0   Premium

# %%
df_relleno = df.fillna(0)  # Con ceros
df_relleno.isnull().sum()
# Out:
# Gasto         0
# Frecuencia    0
# Categoría     0
# dtype: int64

# %%
df_relleno
# Out:
#      Gasto  Frecuencia Categoría
# 0   120.50         2.0    Básico
# 1    85.00         1.0    Básico
# 2   300.00         4.0   Premium
# 3   450.75         6.0   Premium
# 4   210.20         3.0  Estándar
# 5   190.00         3.0  Estándar
# 6   560.00         7.0   Premium
# 7    95.50         2.0    Básico
# 8     0.00         5.0  Estándar
# 9   180.00         0.0    Básico
# 10  275.00         4.0  Estándar
# 11  620.30         8.0   Premium

# %%
df_relleno = df.copy()

# %%
df_relleno.describe()
# Out:
#             Gasto  Frecuencia
# count   11.000000   11.000000
# mean   280.659091    4.090909
# std    185.541751    2.211540
# min     85.000000    1.000000
# 25%    150.250000    2.500000
# 50%    210.200000    4.000000
# 75%    375.375000    5.500000
# max    620.300000    8.000000

# %%
df_relleno = df.fillna(df.mean(numeric_only=True)) # Eso calcula el promedio solo de las columnas numéricas (Gasto, Frecuencia) y rellena sus NaN con ese promedio.

# %%
df_relleno
# Out:
#          Gasto  Frecuencia Categoría
# 0   120.500000    2.000000    Básico
# 1    85.000000    1.000000    Básico
# 2   300.000000    4.000000   Premium
# 3   450.750000    6.000000   Premium
# 4   210.200000    3.000000  Estándar
# 5   190.000000    3.000000  Estándar
# 6   560.000000    7.000000   Premium
# 7    95.500000    2.000000    Básico
# 8   280.659091    5.000000  Estándar
# 9   180.000000    4.090909    Básico
# 10  275.000000    4.000000  Estándar
# 11  620.300000    8.000000   Premium

# %% [markdown]
# <h3>Detección y manejo de valores atípicos</h3>

# %% [markdown]
# <p>Tenemos un listado de clientes con su gasto mensual.
# La mayoría gasta montos razonables… pero hay uno o dos valores raros, muy altos, que pueden distorsionar el análisis.
#
# Eso es exactamente lo que llamamos valores atípicos (outliers).</p>

# %%
#Creamos un dataset de ejemplo
df = pd.DataFrame({
    "Cliente": ["A", "B", "C", "D", "E", "F", "G", "H"],
    "Gasto":   [120, 150, 130, 140, 160, 155, 145, 1200]
})

df
# Out:
#   Cliente  Gasto
# 0       A    120
# 1       B    150
# 2       C    130
# 3       D    140
# 4       E    160
# 5       F    155
# 6       G    145
# 7       H   1200

# %% [markdown]
# <h4>Detección de outliers con el método IQR</h4>

# %% [markdown]
# Entendiendo la idea del método IQR
#
# * Q1 (25%): valores bajos normales
# * Q3 (75%): valores altos normales
# * IQR = rango “normal” del dato
#
# Todo lo que quede muy lejos de ese rango se considera atípico.

# %% [markdown]
# Calcular Q1, Q3 e IQR

# %%
Q1 = df["Gasto"].quantile(0.25)
Q3 = df["Gasto"].quantile(0.75)
IQR = Q3 - Q1

Q1, Q3, IQR
# Out:
# (np.float64(137.5), np.float64(156.25), np.float64(18.75))

# %% [markdown]
# Definir límites

# %%
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# %% [markdown]
# Identificar los outliers

# %%
outliers = df[
    (df["Gasto"] < limite_inferior) |
    (df["Gasto"] > limite_superior)
]

outliers
# Out:
#   Cliente  Gasto
# 7       H   1200

# %% [markdown]
# ¿Qué hacemos con los outliers?

# %%
# 1 Eliminarlos
df_sin_outliers = df[
    (df["Gasto"] >= limite_inferior) &
    (df["Gasto"] <= limite_superior)
]

df_sin_outliers
# Out:
#   Cliente  Gasto
# 0       A    120
# 1       B    150
# 2       C    130
# 3       D    140
# 4       E    160
# 5       F    155
# 6       G    145

# %%
# 2 Reemplazarlos
df_reemplazado = df.copy()

# Convertir en el mismo df donde vas a reemplazar
df_reemplazado["Gasto"] = pd.to_numeric(df_reemplazado["Gasto"], errors="coerce").astype(float)

mediana = df_reemplazado["Gasto"].median()

mask = (df_reemplazado["Gasto"] < limite_inferior) | (df_reemplazado["Gasto"] > limite_superior)
df_reemplazado.loc[mask, "Gasto"] = float(mediana)

df_reemplazado
# Out:
#   Cliente  Gasto
# 0       A  120.0
# 1       B  150.0
# 2       C  130.0
# 3       D  140.0
# 4       E  160.0
# 5       F  155.0
# 6       G  145.0
# 7       H  147.5

# %% [markdown]
# <h3>Formatos alternativos para grandes volúmenes de datos</h3>

# %%
import pandas as pd

df = pd.DataFrame({
    "id": [1, 2, 3, 4],
    "cliente": ["A", "B", "C", "D"],
    "gasto": [120.5, 85.0, 300.0, 450.75],
    "fecha": pd.to_datetime(["2026-01-01", "2026-01-02", "2026-01-03", "2026-01-04"])
})

df
# Out:
#    id cliente   gasto      fecha
# 0   1       A  120.50 2026-01-01
# 1   2       B   85.00 2026-01-02
# 2   3       C  300.00 2026-01-03
# 3   4       D  450.75 2026-01-04

# %% [markdown]
# <h4>Parquet (ideal para análisis, comprimido, rápido)</h4>

# %%
#pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-23.0.0-cp311-cp311-macosx_12_0_x86_64.whl.metadata (3.0 kB)
# Downloading pyarrow-23.0.0-cp311-cp311-macosx_12_0_x86_64.whl (35.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.8/35.8 MB 3.7 MB/s  0:00:09m0:00:0100:01
# Installing collected packages: pyarrow
# Successfully installed pyarrow-23.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Guardar el DataFrame en formato Parquet
df.to_parquet("datos.parquet", index=False) # guardar
df_parquet = pd.read_parquet("datos.parquet") # leer
df_parquet.head()
# Out:
#    id cliente   gasto      fecha
# 0   1       A  120.50 2026-01-01
# 1   2       B   85.00 2026-01-02
# 2   3       C  300.00 2026-01-03
# 3   4       D  450.75 2026-01-04

# %% [markdown]
# HDF5 (útil para guardar “datasets” grandes y estructurados)

# %%
#pip install tables
# Out:
# Collecting tables
#   Downloading tables-3.10.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy>=1.20.0 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from tables) (2.4.0)
# Requirement already satisfied: numexpr>=2.6.2 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from tables) (2.11.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from tables) (25.0)
# Collecting py-cpuinfo (from tables)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting blosc2>=2.3.0 (from tables)
#   Downloading blosc2-3.12.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from tables) (4.15.0)
# Collecting ndindex (from blosc2>=2.3.0->tables)
#   Downloading ndindex-1.10.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.6 kB)
# Collecting msgpack (from blosc2>=2.3.0->tables)
#   Downloading msgpack-1.1.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: platformdirs in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from blosc2>=2.3.0->tables) (4.5.1)
# Collecting numexpr>=2.6.2 (from tables)
#   Downloading numexpr-2.14.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: requests in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from blosc2>=2.3.0->tables) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from requests->blosc2>=2.3.0->tables) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from requests->blosc2>=2.3.0->tables) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from requests->blosc2>=2.3.0->tables) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from requests->blosc2>=2.3.0->tables) (2026.1.4)
# Downloading tables-3.10.2-cp311-cp311-macosx_10_9_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 3.9 MB/s  0:00:01 eta 0:00:01
# Downloading blosc2-3.12.2-cp311-cp311-macosx_10_9_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 3.9 MB/s  0:00:00 eta 0:00:01m
# Downloading numexpr-2.14.1-cp311-cp311-macosx_10_9_x86_64.whl (163 kB)
# Downloading msgpack-1.1.2-cp311-cp311-macosx_10_9_x86_64.whl (82 kB)
# Downloading ndindex-1.10.1-cp311-cp311-macosx_10_9_x86_64.whl (172 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, numexpr, ndindex, msgpack, blosc2, tables
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.11.0
#     Uninstalling numexpr-2.11.0:
#       Successfully uninstalled numexpr-2.11.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [tables]2m5/6 [tables]]
# Successfully installed blosc2-3.12.2 msgpack-1.1.2 ndindex-1.10.1 numexpr-2.14.1 py-cpuinfo-9.0.0 tables-3.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
df.to_hdf("datos.h5", key="df", mode="w")      # guardar
df_hdf = pd.read_hdf("datos.h5", key="df")     # leer
df_hdf.head()
# Out:
#    id cliente   gasto      fecha
# 0   1       A  120.50 2026-01-01
# 1   2       B   85.00 2026-01-02
# 2   3       C  300.00 2026-01-03
# 3   4       D  450.75 2026-01-04

# %% [markdown]
# Feather (muy rápido, intercambio Python ↔ R, también usa Arrow)

# %%
# pip install pyarrow

# %%
df.to_feather("datos.feather")            # guardar
df_feather = pd.read_feather("datos.feather")  # leer
df_feather.head()
# Out:
#    id cliente   gasto      fecha
# 0   1       A  120.50 2026-01-01
# 1   2       B   85.00 2026-01-02
# 2   3       C  300.00 2026-01-03
# 3   4       D  450.75 2026-01-04

# %% [markdown]
# <h3>Conexión con bases de datos</h3>
# SQLite viene incluido por defecto con Python.

# %% [markdown]
# SQLite en 1 minuto
#
# ¿Qué es?
# SQLite es una base de datos relacional que vive en un archivo .db.
# No necesita servidor (a diferencia de PostgreSQL/MySQL). Ideal para demos, proyectos pequeños y prototipos.

# %%
import sqlite3
print(sqlite3.sqlite_version)
# Out:
# 3.50.2

# %%
import sqlite3
import pandas as pd

# Conectar (o crear) base
conn = sqlite3.connect("prueba.db")

# Crear DataFrame simple
df = pd.DataFrame({
    "id": [1, 2, 3],
    "nombre": ["Ana", "Juan", "María"]
})

# Guardar en SQLite
df.to_sql("personas", conn, if_exists="replace", index=False)

# Leer desde SQLite
df_leido = pd.read_sql("SELECT * FROM personas", conn)
print(df_leido)

conn.close()
# Out:
#    id nombre
# 0   1    Ana
# 1   2   Juan
# 2   3  María

# %% [markdown]
# <h4>SQLite desde Python</h4>

# %% [markdown]
# Insertar un registro

# %%
conn = sqlite3.connect("prueba.db")
conn.execute("INSERT INTO personas (id, nombre) VALUES (?, ?)", (4, "Sofía"))
conn.commit()
conn.close()

# %%
# Leer desde SQLite
conn = sqlite3.connect("prueba.db")
df_leido = pd.read_sql("SELECT * FROM personas", conn)
print(df_leido)
# Out:
#    id nombre
# 0   1    Ana
# 1   2   Juan
# 2   3  María
# 3   4  Sofía

# %% [markdown]
# Actualizar

# %%
conn = sqlite3.connect("prueba.db")
conn.execute("UPDATE personas SET nombre = ? WHERE id = ?", ("Juan Pablo", 2))
conn.commit()
conn.close()

# %%
# Leer desde SQLite
conn = sqlite3.connect("prueba.db")
df_leido = pd.read_sql("SELECT * FROM personas", conn)
print(df_leido)
# Out:
#    id      nombre
# 0   1         Ana
# 1   2  Juan Pablo
# 2   3       María
# 3   4       Sofía

# %% [markdown]
# Eliminar

# %%
conn = sqlite3.connect("prueba.db")
conn.execute("DELETE FROM personas WHERE id = ?", (1,))
conn.commit()
conn.close()

# %%
conn = sqlite3.connect("prueba.db")
df = pd.read_sql("SELECT * FROM personas", conn)
conn.close()
df
# Out:
#    id      nombre
# 0   2  Juan Pablo
# 1   3       María
# 2   4       Sofía

# %% [markdown]
# <h3>Obtención de datos desde APIs</h3>
# Muchos servicios web ofrecen APIs que permiten acceder a datos de forma programática. Pandas puede trabajar con estos datos una vez obtenidos:

# %%
import requests
import pandas as pd

# Realizar solicitud a la API
url = 'https://api.exchangerate-api.com/v4/latest/USD'
respuesta = requests.get(url)
datos = respuesta.json()

# Convertir a DataFrame
df = pd.DataFrame(datos)
df
# Out:
#                              provider  \
# USD  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWG  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# USD  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ZWG  https://www.exchangerate-api.com/docs/free
# ZWL  https://www.exchangerate-api.com/docs/free
#
#                                       terms base        date  \
# USD  https://www.exchangerate-api.com/terms  USD  2026-01-18
# AED  https://www.exchangerate-api.com/terms  USD  2026-01-18
# AFN  https://www.exchangerate-api.com/terms  USD  2026-01-18
# ALL  https://www.exchangerate-api.com/terms  USD  2026-01-18
# AMD  https://www.exchangerate-api.com/terms  USD  2026-01-18
# ..                                      ...  ...         ...
# YER  https://www.exchangerate-api.com/terms  USD  2026-01-18
# ZAR  https://www.exchangerate-api.com/terms  USD  2026-01-18
# ZMW  https://www.exchangerate-api.com/terms  USD  2026-01-18
# ZWG  https://www.exchangerate-api.com/terms  USD  2026-01-18
# ZWL  https://www.exchangerate-api.com/terms  USD  2026-01-18
#
#      time_last_updated   rates
# USD         1768694401    1.00
# AED         1768694401    3.67
# AFN         1768694401   66.00
# ALL         1768694401   83.00
# AMD         1768694401  379.94
# ..                 ...     ...
# YER         1768694401  238.45
# ZAR         1768694401   16.40
# ZMW         1768694401   19.97
# ZWG         1768694401   25.61
# ZWL         1768694401   25.61
#
# [166 rows x 7 columns]

# %%
# Procesar y guardar
df.to_csv('datos_api.csv', index=False)

# %% [markdown]
# <h3>Ejemplo de obtención desde Yahoo Finance</h3>

# %%
#pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (1.0)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from yfinance) (2.3.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from yfinance) (6.33.4)
# Requirement already satisfied: websockets>=13.0 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/bootcamp/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import yfinance as yf

# Obtener datos históricos de una acción
ticker = 'AAPL'
periodo = '1y' # 1 año
df = yf.download(ticker, period=periodo)

# Mostrar los primeros registros
print(df.head())

# Guardar en CSV
df.to_csv(f'{ticker}_historico.csv')

# Calcular rendimientos diarios
df['Rendimiento'] = df['Close'].pct_change() * 100

# Visualizar rendimientos
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
df['Rendimiento'].plot()
plt.title(f'Rendimiento diario de {ticker}')
plt.savefig(f'{ticker}_rendimiento.png')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-01-17  228.944534  231.244131  227.451288  231.074899  68488300
# 2025-01-21  221.637573  223.409558  218.392257  222.991451  98070400
# 2025-01-22  222.822235  223.110923  218.800416  218.800416  64126500
# 2025-01-23  222.653000  226.007822  221.299123  223.728139  60234800
# 2025-01-24  221.776947  224.614121  220.413120  223.767942  54697900
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
